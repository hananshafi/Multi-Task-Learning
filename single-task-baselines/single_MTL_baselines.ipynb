# %%
from keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.applications import ResNet50 #VGG16,InceptionV3, MobileNetV2
#from keras.applications.vgg16 import preprocess_input
#from keras.applications.mobilenetv2 import preprocess_input
from keras.datasets import cifar10
#from keras.applications.resnet50 import preprocess_input
from keras.preprocessing import image
from tensorflow.keras.layers import AveragePooling2D, Dropout,Flatten, Dense, Input, BatchNormalization,Activation,Conv2D, MaxPooling2D,GlobalMaxPooling2D,Reshape,Conv2DTranspose,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os
import pandas as pd
from PIL import Image
import random
import tensorflow as tf
from keras.callbacks import History
from tensorflow.keras import backend as K

# %%
# load dataset
(trainX, trainy), (testX, testy) = cifar10.load_data()

# %%
w=10
h=10
fig=plt.figure(figsize=(10, 10))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = random.choice(trainX)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
def process_data(train,test):

  train_norm = train.astype('float32')
  test_norm = test.astype('float32')
  train_norm = train_norm / 255.0
  test_norm = test_norm / 255.0
  return train_norm, test_norm

def get_categorical(y_train,y_test):
  trainY = to_categorical(y_train)
  testY = to_categorical(y_test)
  return trainY, testY

# %%
print(trainX[0].shape)
# Out:
# (32, 32, 3)

# %%
class GetData():
  
  def __init__(self):

    self.class_dict = { 0: 'airplane',1: 'automobile',2: 'bird',3: 'cat',4: 'deer',5: 'dog',6: 'frog',7: 'horse',8: 'ship',9: 'truck'}
    self.animal_class = [2,3,4,5,6,7]
    self.transport_class = [0,1,8,9]
    self.X_train,self.X_test = process_data(trainX,testX)
    self.y_train, self.y_test = trainy, testy

  # task a: individual category classes
  def task_a(self):
      y_train_a,y_test_a = get_categorical(self.y_train,self.y_test)
      return y_train_a, y_test_a
    
  # task b: animal (0) vs transport (1)
  def task_b(self):
      y_train_b = np.array([np.array([0]) if i[0] in self.animal_class else np.array([1]) for i in  self.y_train])
      y_test_b = np.array([np.array([0]) if i[0] in self.animal_class else np.array([1]) for i in  self.y_test])
      y_train_b, y_test_b = get_categorical(y_train_b,y_test_b)
      return y_train_b, y_test_b

  # task c: reconstruction
  def task_c(self):
      return self.X_train, self.X_test
  
  # task d: random labels
  def task_d(self):
    y_train_d = np.array([ np.array(random.choice([0,1])) for i in  self.y_train])
    y_test_d = np.array([np.array(random.choice([0,1])) for i in  self.y_test])
    y_train_d, y_test_d = get_categorical(y_train_d,y_test_d)
    return y_train_d, y_test_d

# %%
get_data = GetData()
X_train, X_test = get_data.X_train, get_data.X_test

(y_train_a,y_test_a) = get_data.task_a()
(y_train_b, y_test_b) = get_data.task_b()
(y_train_c ,y_test_c) = get_data.task_c()
(y_train_d ,y_test_d) = get_data.task_d()

# %%
#Define neural network parameters

class ModelParams():

  def __init__(self):
    self.n_classes_a = 10
    self.n_classes_b = 2
    self.epochs= 10000
    self.lr = 1e-3
    self.BS = 128
    self.iter_epoch = len(trainX)// self.BS
    self.save_period = 10
    self.latent_size = 32
    self.depth = 3
    #self.checkpoint_path = "./content/model_checkpoints"
    #if not os.path.exists(self.checkpoint_path):
    #    os.mkdir(self.checkpoint_path)

    #self.tb_log_path = "./content/tensorboard_logs"
    #if not os.path.exists(self.tb_log_path):
    #    os.mkdir(self.tb_log_path)
        
    #self.tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=self.tb_log_path)


    # #self.cp_callback = tf.keras.callbacks.ModelCheckpoint(
    #     filepath=self.checkpoint_path, 
    #     verbose=1, 
    #     save_weights_only=True,
    #     save_freq= int(self.save_period * self.iter_epoch))

    self.history = History()

# %%
model_params = ModelParams()

# %%
#Build the shared model network



def BuildModel():
  input_shape = (32, 32, 3)
  input = Input(shape=input_shape)
  x = Conv2D(16, kernel_size=3, activation='relu', padding='same')(input)
  #x = Dropout(0.2)(x)
  x = MaxPooling2D(pool_size=(2, 2))(x)
  x = Conv2D(32, kernel_size=3, activation='relu', padding='same')(x)
  x = Dropout(0.2)(x)
  # x = MaxPooling2D(pool_size=(2, 2))(x)
  # x = Conv2D(64, kernel_size=3, activation='relu', padding='same')(x)
  # x = Dropout(0.2)(x)
  y = GlobalMaxPooling2D()(x)

  volumeSize = K.int_shape(x)
  f = Flatten()(x)
  latent = Dense(model_params.latent_size)(f)


  #task a output
  dense_a = Dense(256, activation="relu")(y)
  output_a = Dense(y_train_a.shape[1], activation='softmax', name = 'cifar10_original')(dense_a)

  #task b output
  dense_b  = Dense(256, activation="relu")(y)
  output_b = Dense(y_train_b.shape[1], activation='softmax', name = 'animal_vs_transport')(dense_b)

  #task c output  
  dense_c = Dense(np.prod(volumeSize[1:]))(latent) #(latentInputs)
  inp_c = Reshape((volumeSize[1], volumeSize[2], volumeSize[3]))(dense_c)
  
  #(decoder network for task c)
  #x_c = Conv2DTranspose(64, kernel_size=3, activation='relu', padding='same')(inp_c)
  #x_c = MaxPooling2D(pool_size=(2, 2))(x_c)
  x_c = Conv2DTranspose(32, kernel_size=3, activation='relu', padding='same')(inp_c)
  #x_c = MaxPooling2D(pool_size=(2, 2))(x_c)
  x_c = Conv2DTranspose(16, kernel_size=3, activation='relu', padding='same',strides =2)(x_c)
  #x_c = MaxPooling2D(pool_size=(2, 2))(x_c)
  
  output_c = Conv2DTranspose(model_params.depth, (3, 3), activation='sigmoid',padding="same",name = 'reconstruction')(x_c)
  
  #task d output
  dense_d  = Dense(256, activation="relu")(y)
  output_d = Dense(y_train_d.shape[1], activation='softmax', name = 'random')(dense_d)

  model = Model(inputs=input, outputs=[output_a, output_b, output_c])
  model_cifar = Model(inputs=input, outputs=output_a)
  model_an_vs_non = Model(inputs=input, outputs=output_b)
  model_recon = Model(inputs=input, outputs=output_c)
  # #Geometric mean of losses
  # label_layer_a = Input((1,)) 
  # label_layer_b = Input((1,))
  # label_layer_c = Input(input_shape)
  # label_layer_d = Input((1,))
  # custom_loss = gm_metric.update_state([tf.keras.losses.CategoricalCrossentropy(output_a,label_layer_a),tf.keras.losses.BinaryCrossentropy(output_b,label_layer_b), 
  #                                       tf.keras.losses.KLDivergence(output_c,label_layer_c),tf.keras.losses.BinaryCrossentropy(output_d,label_layer_d) ]).result()
  
  # model.add_loss(custom_loss)


  # print(model.summary())
  # # model.compile(loss=['categorical_crossentropy', 'binary_crossentropy', 'mse','binary_crossentropy'],
  # #               optimizer=Adam(clipnorm = 1.), metrics = {'cifar10_original': 'accuracy','animal_vs_transport':'accuracy',
  # #                                                       'reconstruction':'mean_squared_error','random':'accuracy'}, loss_weights = [0.5, 0.1, 1,0.1])
  # model.compile(
  #                optimizer=Adam(clipnorm = 1.))
  return model,model_cifar,model_an_vs_non,model_recon

# %%
model_mtl1, model_cifar,model_an_vs_non, model_recon  = BuildModel()

# %%
model_recon.compile(loss='mse',
                optimizer=Adam(clipnorm = 1.,lr=model_params.lr), metrics = {'reconstruction': 'mean_squared_error'})
model_recon.fit(X_train,y_train_c,
                    steps_per_epoch = model_params.iter_epoch,
                    epochs = model_params.epochs,
                    validation_data=(X_test,y_test_c),batch_size=model_params.BS,callbacks=[model_params.history],shuffle=True)
# Out:
# Epoch 1/10000
# 390/390 [==============================] - 100s 254ms/step - loss: 0.0338 - mean_squared_error: 0.0338 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 2/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 3/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 4/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 5/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 6/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 7/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 8/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 9/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 10/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 11/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 12/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 13/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 14/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 15/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 16/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 17/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 18/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 19/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 20/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 21/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 22/10000
# 390/390 [==============================] - 100s 256ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 23/10000
# 390/390 [==============================] - 100s 256ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 24/10000
# 390/390 [==============================] - 100s 256ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 25/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 26/10000
# 390/390 [==============================] - 100s 255ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 27/10000
# 390/390 [==============================] - 100s 255ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 28/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 29/10000
# 390/390 [==============================] - 100s 256ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 30/10000
# 390/390 [==============================] - 100s 255ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 31/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 32/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 33/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 34/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 35/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 36/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 37/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 38/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 39/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 40/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 41/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 42/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 43/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 44/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 45/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 46/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 47/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 48/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 49/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 50/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 51/10000
# 390/390 [==============================] - 98s 253ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 52/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 53/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 54/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 55/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 56/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 57/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 58/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 59/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 60/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 61/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 62/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 63/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 64/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 65/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 66/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 67/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 68/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 69/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 70/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 71/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 72/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 73/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 74/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 75/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 76/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 77/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 78/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 79/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 80/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 81/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 82/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 83/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 84/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 85/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 86/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 87/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 88/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 89/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 90/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 91/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 92/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 93/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 94/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 95/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 96/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 97/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 98/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 99/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 100/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 101/10000
# 390/390 [==============================] - 98s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 102/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 103/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 104/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 105/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 106/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 107/10000
# 390/390 [==============================] - 98s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 108/10000
# 390/390 [==============================] - 98s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 109/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 110/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 111/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 112/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 113/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 114/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 115/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 116/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 117/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 118/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 119/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 120/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 121/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 122/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 123/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 124/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 125/10000
# 390/390 [==============================] - 98s 251ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 126/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 127/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 128/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 129/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 130/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 131/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 132/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 133/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 134/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 135/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 136/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 137/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 138/10000
# 390/390 [==============================] - 98s 252ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 139/10000
# 390/390 [==============================] - 98s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 140/10000
# 390/390 [==============================] - 99s 255ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 141/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 142/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 143/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 144/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 145/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 146/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 147/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 148/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 149/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 150/10000
# 390/390 [==============================] - 99s 253ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 151/10000
# 390/390 [==============================] - 99s 254ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 152/10000
# 200/390 [==============>...............] - ETA: 45s - loss: 0.0109 - mean_squared_error: 0.0109
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-e00d22bc38bd> in <module>()
#       4                     steps_per_epoch = model_params.iter_epoch,
#       5                     epochs = model_params.epochs,
# ----> 6                     validation_data=(X_test,y_test_c),batch_size=model_params.BS,callbacks=[model_params.history],shuffle=True)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model_cifar.compile(loss='categorical_crossentropy',
                optimizer=Adam(clipnorm = 1.), metrics = {'cifar10_original': 'accuracy'})
model_cifar.fit(X_train,y_train_a,
                    steps_per_epoch = model_params.iter_epoch,
                    epochs = model_params.epochs,
                    validation_data=(X_test,y_test_a),batch_size=model_params.BS,callbacks=[model_params.history],shuffle=True)

# %%
#evaluate model


eval_list = model_cifar.evaluate(X_test,y_test_a)
print('Test Loss: ',eval_list[0])
print('Test Accuracy: ',eval_list[1])

# %%
#Cifar10 Model Loss Visualization

plt.plot(model_params.history.history['loss'])
plt.plot(model_params.history.history['val_loss'])
plt.title('Cifar10 model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
#Animal vs Non-Anomal Accuracy

plt.plot(model_params.history.history['accuracy'])
plt.plot(model_params.history.history['val_accuracy'])
plt.title('Cifar10 model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
#cifar10 
# Epoch 290/10000 : loss: 0.4114 - accuracy: 0.8527 - val_loss: 0.7509 - val_accuracy: 0.7418

# %%
#recon Model Loss Visualization

plt.plot(model_params.history.history['loss'])
plt.plot(model_params.history.history['val_loss'])
plt.title('Reconstruction model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
#recon Model Loss Visualization
# latent 16
plt.plot(model_params.history.history['loss'])
plt.plot(model_params.history.history['val_loss'])
plt.title('Reconstruction model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
predictions = model_recon.predict(X_test)

# %%
plt.imshow(predictions[45])

# %%
w=10
h=10
fig=plt.figure(figsize=(10, 10))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = random.choice(predictions)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
#recon Model Loss Visualization
#latent = 8
# conv: [8,16]
plt.plot(model_params.history.history['loss'])
plt.plot(model_params.history.history['val_loss'])
plt.title('Reconstruction model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
predictions = model_recon.predict(X_test)

# %%
w=10
h=10
fig=plt.figure(figsize=(10, 10))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = random.choice(predictions)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
#recon Model Loss Visualization
#latent = 8
# conv: [4,8]

plt.plot(model_params.history.history['loss'])
plt.plot(model_params.history.history['val_loss'])
plt.title('Reconstruction model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
predictions = model_recon.predict(X_test)
w=10
h=10
fig=plt.figure(figsize=(10, 10))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = random.choice(predictions)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
#recon Model Loss Visualization
#latent = 32
#conv = [16,32]


plt.plot(model_params.history.history['loss'])
plt.plot(model_params.history.history['val_loss'])
plt.title('Reconstruction model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
predictions = model_recon.predict(X_test)
w=10
h=10
fig=plt.figure(figsize=(10, 10))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = random.choice(predictions)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()
